# %%
import cv2
import copy
import matplotlib.pyplot as plt

# %%
img = cv2.imread('logo.png')

plt.figure()
# OpenCV image channel is BGR so we flip the channels to RGB
plt.imshow(img[:,:,::-1])
plt.show()

# %%
img_cpy = copy.deepcopy(img)
start_point = (120,60)
end_point = (135, 75)
color = (255, 0, 0)
thickness = 2
img_cpy = cv2.rectangle(img_cpy, start_point, end_point, color, thickness)

color = (0, 0, 255)
font = cv2.FONT_HERSHEY_SIMPLEX
fontScale = 1
org = (70, 30)
img_cpy = cv2.putText(img_cpy, 'OpenCV', org, font, 
                   fontScale, color, thickness, cv2.LINE_AA)
plt.imshow(img_cpy[:,:,::-1])
plt.show()
